# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.chdir("C:\\Users\\Chandana\\Desktop\\JLC\\Capstone Project for Advanced Analytics\\Project 2")

# %%
hrdata=pd.read_csv("employee data.csv")

# %%
hrdata.shape
# Out:
# (54808, 14)

# %%
hrdata.head()
# Out:
#    employee_id      department     region  education gender  \
# 0        65438  SalesMarketing   region_7    Masters      f
# 1        65141      Operations  region_22  Bachelors      m
# 2         7513  SalesMarketing  region_19  Bachelors      m
# 3         2542  SalesMarketing  region_23  Bachelors      m
# 4        48945      Technology  region_26  Bachelors      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                     5
# 1               other                1   30                     5
# 2            sourcing                1   34                     3
# 3               other                2   39                     1
# 4               other                1   45                     3
#
#    length_of_service  KPIs_met >80%  awards_won  avg_training_score  \
# 0                  8              1           0                  49
# ...

# %%
hrdata.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
hrdata.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          54808.000000
# mean   39195.830627         1.253011     34.803915              3.078748
# std    22586.581449         0.609264      7.660169              1.496458
# min        1.000000         1.000000     20.000000              0.000000
# 25%    19669.750000         1.000000     29.000000              2.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%    awards_won  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
hrdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
# employee_id             54808 non-null int64
# department              54808 non-null object
# region                  54808 non-null object
# education               54808 non-null object
# gender                  54808 non-null object
# recruitment_channel     54808 non-null object
# no_of_trainings         54808 non-null int64
# age                     54808 non-null int64
# previous_year_rating    54808 non-null int64
# length_of_service       54808 non-null int64
# KPIs_met >80%           54808 non-null int64
# awards_won              54808 non-null int64
# avg_training_score      54808 non-null int64
# is_promoted             54808 non-null int64
# dtypes: int64(9), object(5)
# memory usage: 5.9+ MB

# %%
hrdata.isnull().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won              0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %%
hrdata.dtypes
# Out:
# employee_id              int64
# department              object
# region                  object
# education               object
# gender                  object
# recruitment_channel     object
# no_of_trainings          int64
# age                      int64
# previous_year_rating     int64
# length_of_service        int64
# KPIs_met >80%            int64
# awards_won               int64
# avg_training_score       int64
# is_promoted              int64
# dtype: object

# %%
hrdata["department"].unique()
# Out:
# array(['SalesMarketing', 'Operations', 'Technology', 'Analytics', 'RandD',
#        'Procurement', 'Finance', 'HR', 'Legal'], dtype=object)

# %%
hrdata['department'].value_counts()
# Out:
# SalesMarketing    16840
# Operations        11348
# Technology         7138
# Procurement        7138
# Analytics          5352
# Finance            2536
# HR                 2418
# Legal              1039
# RandD               999
# Name: department, dtype: int64

# %%
hrdata['education'].value_counts()
# Out:
# Bachelors         36669
# Masters           14925
# NotSpecified       2409
# BelowSecondary      805
# Name: education, dtype: int64

# %%
hrdata['gender'].value_counts()
# Out:
# m    38496
# f    16312
# Name: gender, dtype: int64

# %%
hrdata['is_promoted'].value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %%
hrdata.groupby('department').mean()
# Out:
#                  employee_id  no_of_trainings        age  \
# department
# Analytics       39107.191891         1.337818  32.431241
# Finance         39927.936514         1.304022  32.058754
# HR              40036.235318         1.053763  34.385856
# Legal           38154.317613         1.089509  33.832531
# Operations      39125.010575         1.160821  36.073669
# Procurement     39510.594004         1.322779  35.899972
# RandD           38242.011011         1.402402  32.842843
# SalesMarketing  39106.111995         1.277435  34.860629
# Technology      39012.084477         1.260857  34.867190
#
#                 previous_year_rating  length_of_service  KPIs_met >80%  \
# department
# Analytics                   3.247571           4.932735       0.404148
# Finance                     3.115142           4.819401       0.414826
# HR                          3.128619           5.683623       0.334160
# Legal                       2.854668           4.599615       0.333975
# ...

# %%
hrdata.groupby('is_promoted').mean()
# Out:
#               employee_id  no_of_trainings        age  previous_year_rating  \
# is_promoted
# 0            39187.520423         1.257639  34.844037              3.021221
# 1            39285.092331         1.203299  34.372965              3.696658
#
#              length_of_service  KPIs_met >80%  awards_won  avg_training_score
# is_promoted
# 0                     5.879398       0.319685    0.014180           62.647686
# 1                     5.716367       0.698800    0.119751           71.325193

# %%
hrdata.groupby('is_promoted').sum()
# Out:
#              employee_id  no_of_trainings      age  previous_year_rating  \
# is_promoted
# 0             1964862274            63058  1747080                151484
# 1              183382811             5617   160453                 17256
#
#              length_of_service  KPIs_met >80%  awards_won  avg_training_score
# is_promoted
# 0                       294793          16029         711             3141155
# 1                        26684           3262         559              332946

# %%
hrdata.groupby('department')['is_promoted'].value_counts()
# Out:
# department      is_promoted
# Analytics       0               4840
#                 1                512
# Finance         0               2330
#                 1                206
# HR              0               2282
#                 1                136
# Legal           0                986
#                 1                 53
# Operations      0              10325
#                 1               1023
# Procurement     0               6450
#                 1                688
# RandD           0                930
#                 1                 69
# SalesMarketing  0              15627
#                 1               1213
# Technology      0               6370
#                 1                768
# Name: is_promoted, dtype: int64

# %%
sns.countplot(x  ='department', hue='is_promoted',data=hrdata)

# %%
hrdata.groupby('awards_won')['is_promoted'].value_counts()
# Out:
# awards_won  is_promoted
# 0           0              49429
#             1               4109
# 1           0                711
#             1                559
# Name: is_promoted, dtype: int64

# %%
sns.countplot(x  ='awards_won', hue='is_promoted',data=hrdata)

# %%
hrdata.groupby('length_of_service')['is_promoted'].value_counts()
# Out:
# length_of_service  is_promoted
# 1                  0              4170
#                    1               377
# 2                  0              6089
#                    1               595
# 3                  0              6424
#                    1               609
# 4                  0              6238
#                    1               598
# 5                  0              5357
#                    1               475
# 6                  0              4333
#                    1               401
# 7                  0              5087
#                    1               464
# 8                  0              2614
#                    1               269
# 9                  0              2400
#                    1               229
# 10                 0              1989
#                    1               204
# 11                 0               820
#                    1                96
# 12                 0               731
# ...

# %%
sns.countplot(x  ='length_of_service', hue='is_promoted',data=hrdata)

# %%
hrdata.groupby('gender')['is_promoted'].value_counts()
# Out:
# gender  is_promoted
# f       0              14845
#         1               1467
# m       0              35295
#         1               3201
# Name: is_promoted, dtype: int64

# %%
sns.countplot(x  ='gender', hue='is_promoted',data=hrdata)

# %%
hrdata.groupby('avg_training_score')['is_promoted'].value_counts()
# Out:
# avg_training_score  is_promoted
# 39                  0                 2
# 40                  0                 5
# 41                  0                25
#                     1                 1
# 42                  0                60
#                     1                 2
# 43                  0               169
#                     1                 7
# 44                  0               325
#                     1                10
# 45                  0               650
#                     1                31
# 46                  0              1100
#                     1                36
# 47                  0              1667
#                     1                79
# 48                  0              2341
#                     1                96
# 49                  0              2581
#                     1               100
# 50                  0              2604
#                     1               112
# 51                  0              2244
# ...

# %%
sns.countplot(x  ='avg_training_score', hue='is_promoted',data=hrdata)

# %%
hrdata.groupby('previous_year_rating')['is_promoted'].value_counts()
# Out:
# previous_year_rating  is_promoted
# 0                     0               3785
#                       1                339
# 1                     0               6135
#                       1                 88
# 2                     0               4044
#                       1                181
# 3                     0              17263
#                       1               1355
# 4                     0               9093
#                       1                784
# 5                     0               9820
#                       1               1921
# Name: is_promoted, dtype: int64

# %%
sns.countplot(x  ='previous_year_rating', hue='is_promoted',data=hrdata)

# %%
hrdata.groupby('education')['is_promoted'].value_counts()
# Out:
# education       is_promoted
# Bachelors       0              33661
#                 1               3008
# BelowSecondary  0                738
#                 1                 67
# Masters         0              13454
#                 1               1471
# NotSpecified    0               2287
#                 1                122
# Name: is_promoted, dtype: int64

# %%
sns.countplot(x  ='education', hue='is_promoted',data=hrdata)

# %%
hrdata['length_of_service'].value_counts()
# Out:
# 3     7033
# 4     6836
# 2     6684
# 5     5832
# 7     5551
# 6     4734
# 1     4547
# 8     2883
# 9     2629
# 10    2193
# 11     916
# 12     794
# 13     687
# 15     593
# 14     549
# 16     548
# 17     432
# 18     392
# 19     329
# 20     128
# 21      78
# 24      70
# 23      65
# 22      61
# 25      51
# 26      41
# 27      36
# 28      30
# 29      30
# 31      20
# 30      12
# 32      10
# 33       9
# 34       4
# 37       1
# Name: length_of_service, dtype: int64

# %%
hrdata['previous_year_rating'].value_counts()
# Out:
# 3    18618
# 5    11741
# 4     9877
# 1     6223
# 2     4225
# 0     4124
# Name: previous_year_rating, dtype: int64

# %%
sns.countplot(hrdata.department)
plt.show()

# %%
#Sales marketing department has the largest number of workforce, and r&D the lowest.

# %%
sns.countplot(hrdata.education)
plt.show()

# %%
#Bachelors education background is of the greatest number of employees, followed by Masters.
#2. Below secondary  has the lowest number of employees in it.

# %%
sns.countplot(hrdata.gender)
plt.show()

# %%
#number of male employees are more compared to females

# %%
sns.countplot(hrdata.recruitment_channel)
plt.show()

# %%
sns.countplot(hrdata.no_of_trainings)
plt.show()

# %%
sns.countplot(hrdata.length_of_service)
plt.show()

# %%
sns.countplot(x  ='is_promoted', hue='gender',data=hrdata)

# %%
sns.countplot(x  ='department', hue='gender',data=hrdata)

# %%
sns.countplot(x  ='is_promoted', hue='department',data=hrdata)

# %%
sns.countplot(x  ='awards_won', hue='department',data=hrdata)

# %%
 sns.countplot(x  ='length_of_service', hue='department',data=hrdata)

# %%
sns.countplot(x  ='education', hue='department',data=hrdata)

# %%
sns.countplot(x  ='education', hue='gender',data=hrdata)

# %%
sns.countplot(hrdata.awards_won )
plt.show()

# %%
sns.countplot(hrdata.avg_training_score)
plt.show()

# %%
sns.countplot(hrdata.is_promoted)
plt.show()

# %%
hrdata.hist(figsize=(20,20))
plt.show()

# %%
hrdata.groupby('department')['is_promoted'].mean()
# Out:
# department
# Analytics         0.095665
# Finance           0.081230
# HR                0.056245
# Legal             0.051011
# Operations        0.090148
# Procurement       0.096386
# RandD             0.069069
# SalesMarketing    0.072031
# Technology        0.107593
# Name: is_promoted, dtype: float64

# %%
Technology department employees has promoted more compared to legal depatment

# %%
hrdata.groupby('is_promoted')['department'].count()
# Out:
# is_promoted
# 0    50140
# 1     4668
# Name: department, dtype: int64

# %%
hrdata.groupby('is_promoted')['gender'].count()
# Out:
# is_promoted
# 0    50140
# 1     4668
# Name: gender, dtype: int64

# %%
hrdata.corr()
# Out:
#                       employee_id  no_of_trainings       age  \
# employee_id              1.000000        -0.005121  0.000437
# no_of_trainings         -0.005121         1.000000 -0.081278
# age                      0.000437        -0.081278  1.000000
# previous_year_rating     0.002350        -0.064119  0.177935
# length_of_service        0.001274        -0.057275  0.657111
# KPIs_met >80%           -0.002501        -0.045576 -0.025592
# awards_won               0.008420        -0.007628 -0.008169
# avg_training_score      -0.000586         0.042517 -0.048380
# is_promoted              0.001206        -0.024896 -0.017166
#
#                       previous_year_rating  length_of_service  KPIs_met >80%  \
# employee_id                       0.002350           0.001274      -0.002501
# no_of_trainings                  -0.064119          -0.057275      -0.045576
# age                               0.177935           0.657111      -0.025592
# ...

# %%
hrdata_col1= ['no_of_trainings','previous_year_rating','length_of_service','avg_training_score','is_promoted']
sns.pairplot(hrdata[hrdata_col1], kind="reg", diag_kind = "kde" , hue = 'is_promoted' )
plt.show()
# Out:
# C:\Users\Chandana\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Chandana\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
hrdata_col2= ['department','education','gender','age','length_of_service','avg_training_score','previous_year_rating','is_promoted']
sns.pairplot(hrdata[hrdata_col1], kind="reg", diag_kind = "kde" , hue = 'is_promoted' )
plt.show()

# %%
hrdata.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
hrdata.groupby('is_promoted').mean()
# Out:
#               employee_id  no_of_trainings        age  previous_year_rating  \
# is_promoted
# 0            39187.520423         1.257639  34.844037              3.021221
# 1            39285.092331         1.203299  34.372965              3.696658
#
#              length_of_service  KPIs_met >80%  awards_won  avg_training_score
# is_promoted
# 0                     5.879398       0.319685    0.014180           62.647686
# 1                     5.716367       0.698800    0.119751           71.325193

# %%
hrdata.groupby('department').mean()
# Out:
#                  employee_id  no_of_trainings        age  \
# department
# Analytics       39107.191891         1.337818  32.431241
# Finance         39927.936514         1.304022  32.058754
# HR              40036.235318         1.053763  34.385856
# Legal           38154.317613         1.089509  33.832531
# Operations      39125.010575         1.160821  36.073669
# Procurement     39510.594004         1.322779  35.899972
# RandD           38242.011011         1.402402  32.842843
# SalesMarketing  39106.111995         1.277435  34.860629
# Technology      39012.084477         1.260857  34.867190
#
#                 previous_year_rating  length_of_service  KPIs_met >80%  \
# department
# Analytics                   3.247571           4.932735       0.404148
# Finance                     3.115142           4.819401       0.414826
# HR                          3.128619           5.683623       0.334160
# Legal                       2.854668           4.599615       0.333975
# ...

# %%
# CLUSTERING create employee segments using clustering and visually explore the % of employees promoted in each segment 

#that the most important factor for any employee to get promoted  by experiance, age , rating in the company. 
#So let's bunch them in the group of people using cluster analysis.

# %%
hrdata.columns

# %%
#import module
## Create a cluster model
import sklearn.cluster as cluster
from sklearn.cluster import KMeans
# Filter data
promo_emp =  hrdata[['no_of_trainings', 'age','previous_year_rating','length_of_service']][hrdata.is_promoted == 1]
# Create groups using K-means clustering.
kmeans = KMeans(n_clusters = 5, random_state = 0).fit(promo_emp)

# %%
promo_emp.head()
# Out:
#     no_of_trainings  age  previous_year_rating  length_of_service
# 11                1   35                     5                  3
# 39                1   33                     5                  6
# 60                1   50                     4                 17
# 66                1   27                     0                  1
# 67                1   27                     0                  1

# %%
# Add new column "label" annd assign cluster labels.
promo_emp['label'] = kmeans.labels_
# Draw scatter plot
plt.scatter(promo_emp['no_of_trainings'], promo_emp['age'],c=promo_emp['label'],cmap='Accent')

plt.xlabel('no_of_trainings')
plt.ylabel('age')
plt.title('5 Clusters of employees who promoted')
plt.show()

# %%
# Draw scatter plot
plt.scatter(promo_emp['no_of_trainings'],promo_emp['previous_year_rating'], c=promo_emp['label'],cmap='Accent')

plt.xlabel('no_of_trainings')
plt.ylabel('previous_year_rating')
plt.title('5 Clusters of employees who promoted')
plt.show()

# %%
plt.scatter(promo_emp['no_of_trainings'],promo_emp['length_of_service'], c=promo_emp['label'],cmap='Accent')

plt.xlabel('no_of_trainings')
plt.ylabel('length_of_service')
plt.title('5 Clusters of employees who promoted')
plt.show()

# %%
#Building a Prediction Model
#Pre-Processing Data

# %%
# Import LabelEncoder
from sklearn import preprocessing
#creating labelEncoder
le = preprocessing.LabelEncoder()
# Converting string labels into numbers.

hrdata['department']=le.fit_transform(hrdata['department'])
hrdata['gender']=le.fit_transform(hrdata['gender'])
hrdata['education']=le.fit_transform(hrdata['education'])

# %%
#Split Train and Test Set

# %%
#Spliting data into Feature and test and target
X=hrdata[['department', 'education', 'gender',
       'age', 'no_of_trainings', 'previous_year_rating',
       'avg_training_score','awards_won', 'KPIs_met >80%','length_of_service']]
y=hrdata['is_promoted']

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)  # 70% training and 30% test

# %%
#Model Building ,prediction model.
#using Gradient Boosting Classifier function.

# %%
#Import Gradient Boosting Classifier model
from sklearn.ensemble import GradientBoostingClassifier

#Create Gradient Boosting Classifier
gb = GradientBoostingClassifier()

#Train the model using the training sets
gb.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = gb.predict(X_test)

# %%
#Evaluating Model Performance

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Model Precision
print("Precision:",metrics.precision_score(y_test, y_pred))
# Model Recall
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.9404609864379979
# Precision: 0.9447236180904522
# Recall: 0.2820705176294073

# %%
# we got a classification rate of 94%, considered as good accuracy.

#Precision: Precision is about being precise, i.e., 
#how precise your model is. In this prediction case,
#when Gradient Boosting model predicted an employee is going to promote, that employee actually promoted 94% .
#Recall: If there is an employee who recently promoted in the test set and your Gradient Boosting model can identify it 92% .

# %%
====================================================Concluded=======================================

# %%
#Logistic Regression Model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# C:\Users\Chandana\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
from sklearn.metrics import accuracy_score
print('Logistic regression accuracy: {:.3f}'.format(accuracy_score(y_test, logreg.predict(X_test))))
# Out:
# Logistic regression accuracy: 0.918

# %%
#Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# C:\Users\Chandana\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
print('Random Forest Accuracy: {:.3f}'.format(accuracy_score(y_test, rf.predict(X_test))))
# Out:
# Random Forest Accuracy: 0.930

# %%
#Cross Validation
#Cross validation attempts to avoid overfitting while still producing a prediction for each observation dataset. 
#We are using 10-fold Cross-Validation to train our Random Forest model.

# %%
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
kfold = model_selection.KFold(n_splits=10, random_state=7)
modelCV = RandomForestClassifier()
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, X_train, y_train, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy: %.3f" % (results.mean()))
# Out:
# C:\Users\Chandana\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Chandana\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Chandana\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Chandana\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
#Random Forest Accuracy: 0.931,10-fold cross validation average accuracy: 0.927
# The average accuracy remains very close to the Random Forest model accuracy; hence,
# we can conclude that the model generalizes well.

# %%
#Precision and recall
#We build confusion matrix to visualize predictions made by a classifier and evaluate the accuracy of a classification.

# %%
#Random Forest
from sklearn.metrics import classification_report
print(classification_report(y_test, rf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     15057
#            1       0.67      0.33      0.44      1386
#
#    micro avg       0.93      0.93      0.93     16443
#    macro avg       0.81      0.66      0.70     16443
# weighted avg       0.92      0.93      0.92     16443

# %%
y_pred = rf.predict(X_test)
from sklearn.metrics import confusion_matrix
import seaborn as sns
forest_cm = metrics.confusion_matrix(y_pred, y_test, [1,0])
sns.heatmap(forest_cm, annot=True, 
            fmt='.2f',xticklabels = ["promoted", "not_promoted"] , yticklabels = ["promoted", "not_promoted"])
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Random Forest')
plt.savefig('random_forest')

# %%
#Logistic Regression
print(classification_report(y_test, logreg.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     15057
#            1       0.62      0.07      0.13      1386
#
#    micro avg       0.92      0.92      0.92     16443
#    macro avg       0.77      0.53      0.54     16443
# weighted avg       0.90      0.92      0.89     16443

# %%
logreg_y_pred = logreg.predict(X_test)
logreg_cm = metrics.confusion_matrix(logreg_y_pred, y_test, [1,0])
sns.heatmap(logreg_cm, annot=True, fmt='.2f',xticklabels =["promoted", "not_promoted"] , yticklabels = ["promoted", "not_promoted"])
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.title('Logistic Regression')
plt.savefig('logistic_regression')

# %%
#When an employee promoted, how often does my classifier predict that correctly? This measurement is called “recall”
and a quick look at these diagrams can demonstrate that random forest is clearly best for this criteria. 
Out of all the turnover cases, random forest correctly retrieved to a turnover “recall” of about 99% , 
far better than logistic regression (92%) .

When a classifier predicts an employee will promoted, how often does that employee actually promoted? This measurement is called “precision”. 
Random forest again outperforms the other two at about 94% precision  with logistic regression at about 92% .

# %%
#The ROC Curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
rf_roc_auc = roc_auc_score(y_test, rf.predict(X_test))
rf_fpr, rf_tpr, rf_thresholds = roc_curve(y_test, rf.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot(rf_fpr, rf_tpr, label='Random Forest (area = %0.2f)' % rf_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('ROC')
plt.show()

# %%
#The receiver operating characteristic (ROC) curve is another common tool used with binary classifiers. 
#The dotted line represents the ROC curve of a purely random classifier;
#a good classifier stays as far away from that line as possible (toward the top-left corner).

# %%
#Feature Importance for Random Forest Model
feature_labels = np.array(['department', 'region', 'education', 'gender',
       'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
       'length_of_service', 'KPIs_met >80%', 'awards_won',
       'avg_training_score', 'is_promoted'])
importance = rf.feature_importances_
feature_indexes_by_importance = importance.argsort()
for index in feature_indexes_by_importance:
    print('{}-{:.2f}%'.format(feature_labels[index], (importance[index] *100.0)))
# Out:
# region-2.51%
# education-2.58%
# previous_year_rating-2.69%
# recruitment_channel-3.18%
# length_of_service-4.85%
# no_of_trainings-5.93%
# department-10.96%
# KPIs_met >80%-12.50%
# gender-19.33%
# age-35.48%

# %%
According to our Random Forest model,
the above shows the most important features which influence whether an employee will promote, in ascending order.
